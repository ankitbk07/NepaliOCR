# %%
# import os
# import fitz
# from PIL import Image
# import pytesseract
# import io

# %%
# custom_config = r'-l nep --oem 3 --psm 6'
# pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# %%
# import time

# def measure_time(func):
#     def wrapper(*args, **kwargs):
#         start_time = time.time()  # Record the start time
#         result = func(*args, **kwargs)  # Execute the function
#         end_time = time.time()  # Record the end time
#         execution_time = end_time - start_time  # Calculate the execution time
#         print(f"Function '{func.__name__}' took {execution_time:.6f} seconds to run.")
#         return result
#     return wrapper

# %%
# @measure_time
# # Function to convert PDF to image
# def pdf_to_image(pdf_file, dpi=150):
#     # Open the PDF file
#     pdf = fitz.open(pdf_file)
#     # Get the current page
#     for i in range(pdf.page_count):
#         page = pdf[i]
#         # Render the page to an image
#         pix = page.get_pixmap(dpi=dpi, alpha=False)
#         byte_obj = pix.pil_tobytes(format="png", optimize=True)
#         img = Image.open(io.BytesIO(byte_obj))
#         text = pytesseract.image_to_string(img, config=custom_config)
#         print(f'page {i}')
#         with open('file2.txt', mode = 'a',encoding="utf-8") as f:
#             f.write(text)
#     # Close the PDF file
#     pdf.close()

# # Convert the PDF to images
# pdf_to_image("AllThesis.pdf")

# %%
# import time

# def measure_time(func):
#     def wrapper(*args, **kwargs):
#         start_time = time.time()  # Record the start time
#         result = func(*args, **kwargs)  # Execute the function
#         end_time = time.time()  # Record the end time
#         execution_time = end_time - start_time  # Calculate the execution time
#         print(f"Function '{func.__name__}' took {execution_time:.6f} seconds to run.")
#         return result
#     return wrapper

# %%
#next time convert the all the pdf to images and extract the page to get the text file.

# %%
# @measure_time
# def pdf_to_text(pdf_folder, text_folder, dpi=300):
#     # Iterate over all PDF files in the specified folder
#     for filename in os.listdir(pdf_folder):
#         if filename.endswith('.pdf'):
#             # Construct the full path of the PDF file
#             pdf_file = os.path.join(pdf_folder, filename)

#             # Open the PDF file
#             pdf = fitz.open(pdf_file)

#             # Create a text file name based on the PDF file name
#             text_filename = os.path.splitext(filename)[0] + '.txt'
#             # Construct the full path of the text file
#             text_file = os.path.join(text_folder, text_filename)

#             # Get the current page
#             for i in range(pdf.page_count):
#                 page = pdf[i]
#                 # Render the page to an image
#                 pix = page.get_pixmap(dpi=dpi, alpha=False)
#                 byte_obj = pix.pil_tobytes(format="png", optimize=True)
#                 img = Image.open(io.BytesIO(byte_obj))
#                 text = pytesseract.image_to_string(img, config=custom_config)

#                 # Append the extracted text to the text file
#                 with open(text_file, mode='a', encoding="utf-8") as f:
#                     f.write(text)

#             # Close the PDF file
#             pdf.close()
#             print(f'{filename} is completed')
            
# pdf_to_text('thesis_1','thesis_txt')

# %%
import os
import fitz
from PIL import Image
import pytesseract
import io
from concurrent.futures import ThreadPoolExecutor
import time

custom_config = r'-l nep --oem 3 --psm 6'
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'


# def measure_time(func):
#     def wrapper(args, **kwargs):
#         start_time = time.time()  # Record the start time
#         result = func(args, **kwargs)  # Execute the function
#         end_time = time.time()  # Record the end time
#         execution_time = end_time - start_time  # Calculate the execution time
#         print(f"Function '{func.name}' took {execution_time:.6f} seconds to run.")
#         return result

#     return wrapper


def process_page(page, dpi=300):
    # Render the page to an image
    pix = page.get_pixmap(dpi=dpi, alpha=False)
    byte_obj = pix.pil_tobytes(format="jpeg", optimize=True)
    img = Image.open(io.BytesIO(byte_obj))
#     print(img)
    text = pytesseract.image_to_string(img, config=custom_config)
    return text

# %%
# @measure_time
def pdf_to_text(pdf_folder, text_folder, dpi=150, num_threads=4):
    for filename in os.listdir(pdf_folder):
        if filename.endswith('.pdf'):
            # Construct the full path of the PDF file
            pdf_file = os.path.join(pdf_folder, filename)
        # Open the PDF file
        pdf = fitz.open(pdf_file)
        # Create a text file name based on the PDF file name
        text_filename = os.path.splitext(filename)[0] + '.txt'
        # Construct the full path of the text file
        text_file = os.path.join(text_folder, text_filename)

        # Create a list to store the results for each page
        page_results = []

        # Get the current page
        with ThreadPoolExecutor(max_workers=num_threads) as executor:
            # Process each page concurrently
            futures = [executor.submit(process_page, page, dpi) for page in pdf]

            # Gather the results of each page
            for future in futures:
                page_results.append(future.result())

        # Close the PDF file
        pdf.close()

        # Write the results to the text file in the correct order
        with open(text_file, mode='w', encoding="utf-8") as f:
            for result in page_results:
                f.write(result)

        print(f"PDF to text conversion completed: {pdf_file} -> {text_file}")


pdf_to_text('thesis_1', 'thesis_txt')
# Out:
# PDF to text conversion completed: thesis_1\विष्णु सुवेदीको जीवनी, व्यक्तित्व र कृतित्वको अध्ययन{Bisnu Subediko Jibani, Byaktitwa ra Krititwako Adhyayan}.pdf -> thesis_txt\विष्णु सुवेदीको जीवनी, व्यक्तित्व र कृतित्वको अध्ययन{Bisnu Subediko Jibani, Byaktitwa ra Krititwako Adhyayan}.txt
# PDF to text conversion completed: thesis_1\विष्णुभक्त फुयाँलको जीवनी, व्यक्तित्व र कृतित्व { Bishnubhakta Phuyalko Jeewani, Byaktitwa ra Krititwa}.pdf -> thesis_txt\विष्णुभक्त फुयाँलको जीवनी, व्यक्तित्व र कृतित्व { Bishnubhakta Phuyalko Jeewani, Byaktitwa ra Krititwa}.txt
# PDF to text conversion completed: thesis_1\वीरकालीन कवितामा युगीन प्रभाव {Birkalin Kabitama Yugin Prabhaw}.pdf -> thesis_txt\वीरकालीन कवितामा युगीन प्रभाव {Birkalin Kabitama Yugin Prabhaw}.txt
# PDF to text conversion completed: thesis_1\वैराग्यलहरी खण्डकाव्यमा पूर्वीय दर्शन {Bairagyalahari Khandakabyama Purbiya Darshan}.pdf -> thesis_txt\वैराग्यलहरी खण्डकाव्यमा पूर्वीय दर्शन {Bairagyalahari Khandakabyama Purbiya Darshan}.txt
# PDF to text conversion completed: thesis_1\शक्ति लम्सालको जीवनी, व्यक्तित्व र कृतित्व{Shakti Lamsalko Jibani, Byaktitwa ra Krititwa}.pdf -> thesis_txt\शक्ति लम्सालको जीवनी, व्यक्तित्व र कृतित्व{Shakti Lamsalko Jibani, Byaktitwa ra Krititwa}.txt
# PDF to text conversion completed: thesis_1\शाकुन्तल महाकाव्यमा रसविधान {Shakuntal Mahakavyama Rasvidhan }.pdf -> thesis_txt\शाकुन्तल महाकाव्यमा रसविधान {Shakuntal Mahakavyama Rasvidhan }.txt
# PDF to text conversion completed: thesis_1\शार्दूल भट्टराईको जीवनी,व्यक्तित्व र कृतित्वको अध्ययन {Shardul Bhattarai Jeewani, Byaktitwa ra Krititwako Adhyayan}.pdf -> thesis_txt\शार्दूल भट्टराईको जीवनी,व्यक्तित्व र कृतित्वको अध्ययन {Shardul Bhattarai Jeewani, Byaktitwa ra Krititwako Adhyayan}.txt
# PDF to text conversion completed: thesis_1\शिवसुन्दर पुडासैनीको जीवनी, व्यक्तित्व र कृतित्व {Shivasundar Pudasainiko Jibani, Byaktitwa Ra Krititwa}.pdf -> thesis_txt\शिवसुन्दर पुडासैनीको जीवनी, व्यक्तित्व र कृतित्व {Shivasundar Pudasainiko Jibani, Byaktitwa Ra Krititwa}.txt
# PDF to text conversion completed: thesis_1\शुभ मुकारुङको जीवनी, व्यक्तित्व र कृतित्व{Śubha mukāruṅakō jīvanī, vyaktitva ra kr̥titva}.pdf -> thesis_txt\शुभ मुकारुङको जीवनी, व्यक्तित्व र कृतित्व{Śubha mukāruṅakō jīvanī, vyaktitva ra kr̥titva}.txt
# PDF to text conversion completed: thesis_1\श्यामलका कवितामा अभिव्यञ्जित ध्वन्याथ Syamalaka kavitama abhivyanjita dhvanyatha.pdf -> thesis_txt\श्यामलका कवितामा अभिव्यञ्जित ध्वन्याथ Syamalaka kavitama abhivyanjita dhvanyatha.txt
# PDF to text conversion completed: thesis_1\सङखुवासभा जिल्लाको मकालु गाउंपालिकामा प्रचलित लोककथाको अध्ययन {Sankhuwasabha Jillako Makalu Gawpalikama Prachalit Lokkathako Adhyayan}.pdf -> thesis_txt\सङखुवासभा जिल्लाको मकालु गाउंपालिकामा प्रचलित लोककथाको अध्ययन {Sankhuwasabha Jillako Makalu Gawpalikama Prachalit Lokkathako Adhyayan}.txt
# PDF to text conversion completed: thesis_1\सङखुवासभा जिल्लामा प्रचलित नेपाली लोककथाको विश्लेषण {Sankhuwasabha Jillama Prachalit Nepali Lokkathako Vishleshan}.pdf -> thesis_txt\सङखुवासभा जिल्लामा प्रचलित नेपाली लोककथाको विश्लेषण {Sankhuwasabha Jillama Prachalit Nepali Lokkathako Vishleshan}.txt
# PDF to text conversion completed: thesis_1\सन्ध्या पहाडीको जीवनी, व्यक्तित्व र कृतित्व{Sandhya Pahadiko Jeebani, Byaktitwa ra Krititwa}.pdf -> thesis_txt\सन्ध्या पहाडीको जीवनी, व्यक्तित्व र कृतित्व{Sandhya Pahadiko Jeebani, Byaktitwa ra Krititwa}.txt
# PDF to text conversion completed: thesis_1\सप्तरी जिल्लाका कक्षा सातमा अध्ययनरत मैथिलीभाषी विद्यार्थीहरूले नेपाली उच्चारणमा गर्ने त्रुटिहरूको अध्ययन {Saptari  Jillaka Kakshya Saatma Adhyanrat Maiithalibhashi Bidhyarthiharule Nepali Uchcharanma Garne turtiharuko Adhyayan }.pdf -> thesis_txt\सप्तरी जिल्लाका कक्षा सातमा अध्ययनरत मैथिलीभाषी विद्यार्थीहरूले नेपाली उच्चारणमा गर्ने त्रुटिहरूको अध्ययन {Saptari  Jillaka Kakshya Saatma Adhyanrat Maiithalibhashi Bidhyarthiharule Nepali Uchcharanma Garne turtiharuko Adhyayan }.txt
# PDF to text conversion completed: thesis_1\सप्तरी जिल्लाको धनगढी गाउँ विकास समितिको थारू लोक नाटकको अध्ययन { Saptari Jillako Dhangadi Goun Bikash Samitiko Tharu Lok Natakko Adhyayan}.pdf -> thesis_txt\सप्तरी जिल्लाको धनगढी गाउँ विकास समितिको थारू लोक नाटकको अध्ययन { Saptari Jillako Dhangadi Goun Bikash Samitiko Tharu Lok Natakko Adhyayan}.txt
# PDF to text conversion completed: thesis_1\सप्तरी जिल्लामा प्रचलित थारु भाषाका उखानहरुको अध्ययन {Saptari Jillama Prachalit Tharu Bhasaka Ukhanharuko Adhyayan}.pdf -> thesis_txt\सप्तरी जिल्लामा प्रचलित थारु भाषाका उखानहरुको अध्ययन {Saptari Jillama Prachalit Tharu Bhasaka Ukhanharuko Adhyayan}.txt
# PDF to text conversion completed: thesis_1\समका ऐतिहासिक पद्य नाटकमा पात्रविधान {Samka Aetihasik Padh Natakma Patravidhan}.pdf -> thesis_txt\समका ऐतिहासिक पद्य नाटकमा पात्रविधान {Samka Aetihasik Padh Natakma Patravidhan}.txt
# PDF to text conversion completed: thesis_1\समय,समय अनि समय’ नाटकका विधातात्विक अध्ययन{Thematic Study of the Play 'Time, Time and Time'}.pdf -> thesis_txt\समय,समय अनि समय’ नाटकका विधातात्विक अध्ययन{Thematic Study of the Play 'Time, Time and Time'}.txt
# PDF to text conversion completed: thesis_1\सम्पादकीय सङकथनमा प्रतिनिधित्व (Sampadakiya Sanakathanama Pratinidhitva).pdf -> thesis_txt\सम्पादकीय सङकथनमा प्रतिनिधित्व (Sampadakiya Sanakathanama Pratinidhitva).txt
# PDF to text conversion completed: thesis_1\सम्बन्ध कथा सङग्रहको विधातात्विक अध्ययन {Sambandha Katha Sangrahko Bidhatatwik Adhyayan}.pdf -> thesis_txt\सम्बन्ध कथा सङग्रहको विधातात्विक अध्ययन {Sambandha Katha Sangrahko Bidhatatwik Adhyayan}.txt
# PDF to text conversion completed: thesis_1\सरूभक्तका विज्ञान नाटकमा पात्रविधान { Sarubhaktaka Bigyan Natakma Patravidhan}.pdf -> thesis_txt\सरूभक्तका विज्ञान नाटकमा पात्रविधान { Sarubhaktaka Bigyan Natakma Patravidhan}.txt
