# %%
import os
import fitz
from PIL import Image
import pytesseract
import io

# %%
custom_config = r'-l nep --oem 3 --psm 6'
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# %%
import time

def measure_time(func):
    def wrapper(*args, **kwargs):
        start_time = time.time()  # Record the start time
        result = func(*args, **kwargs)  # Execute the function
        end_time = time.time()  # Record the end time
        execution_time = end_time - start_time  # Calculate the execution time
        print(f"Function '{func.__name__}' took {execution_time:.6f} seconds to run.")
        return result
    return wrapper

# %%
# @measure_time
# # Function to convert PDF to image
# def pdf_to_image(pdf_file, dpi=150):
#     # Open the PDF file
#     pdf = fitz.open(pdf_file)
#     # Get the current page
#     for i in range(pdf.page_count):
#         page = pdf[i]
#         # Render the page to an image
#         pix = page.get_pixmap(dpi=dpi, alpha=False)
#         byte_obj = pix.pil_tobytes(format="png", optimize=True)
#         img = Image.open(io.BytesIO(byte_obj))
#         text = pytesseract.image_to_string(img, config=custom_config)
#         print(f'page {i}')
#         with open('file2.txt', mode = 'a',encoding="utf-8") as f:
#             f.write(text)
#     # Close the PDF file
#     pdf.close()

# # Convert the PDF to images
# pdf_to_image("AllThesis.pdf")

# %%
# import time

# def measure_time(func):
#     def wrapper(*args, **kwargs):
#         start_time = time.time()  # Record the start time
#         result = func(*args, **kwargs)  # Execute the function
#         end_time = time.time()  # Record the end time
#         execution_time = end_time - start_time  # Calculate the execution time
#         print(f"Function '{func.__name__}' took {execution_time:.6f} seconds to run.")
#         return result
#     return wrapper

# %%
#next time convert the all the pdf to images and extract the page to get the text file.

# %%
@measure_time
def pdf_to_text(pdf_folder, text_folder, dpi=300):
    # Iterate over all PDF files in the specified folder
    for filename in os.listdir(pdf_folder):
        if filename.endswith('.pdf'):
            # Construct the full path of the PDF file
            pdf_file = os.path.join(pdf_folder, filename)

            # Open the PDF file
            pdf = fitz.open(pdf_file)

            # Create a text file name based on the PDF file name
            text_filename = os.path.splitext(filename)[0] + '.txt'
            # Construct the full path of the text file
            text_file = os.path.join(text_folder, text_filename)

            # Get the current page
            for i in range(pdf.page_count):
                page = pdf[i]
                # Render the page to an image
                pix = page.get_pixmap(dpi=dpi, alpha=False)
                byte_obj = pix.pil_tobytes(format="png", optimize=True)
                img = Image.open(io.BytesIO(byte_obj))
                text = pytesseract.image_to_string(img, config=custom_config)

                # Append the extracted text to the text file
                with open(text_file, mode='a', encoding="utf-8") as f:
                    f.write(text)

            # Close the PDF file
            pdf.close()
            print(f'{filename} is completed')
            
pdf_to_text('thesis_1','thesis_txt')
# Out:
# अछामी गाउँखाने कथाको अध्ययन { Achhami Gawkhane Kathako Adhyayan}.pdf is completed
# अभय श्रेष्ठ(चङकी)को जीवनी, व्यक्तित्व र कृतित्वको अध्ययन {Abhay Shrestha(Chanki)ko Jeebani, Byaktitwa a Krititwako Adhyayan}.pdf is completed
# अर्घाखाची जिल्लाको पश्चिमी भेगका लोकगीतको अध्ययन {Arghakhaci Jillako Paschimi Bhegaka Lokagitako Adhyayan}.pdf is completed
# अलिखित उपन्यासको पात्र विधान {Alikhit Upanyasko Patra Vidhan}.pdf is completed
# विजय मल्लका दोस्रो चरणका एकाङ्कीमा समाज मनोविज्ञान {Bijaya Mallaka Dosro Charanka Ekankima Samaj Manobigyan}.pdf is completed
# विजय मल्लको कुमारी शोभा उपन्यासमा मनोविश्लेषण {Bijaya Mallako Kumari Shobha Upanyasma Manobishleshan}.pdf is completed
# विजय मल्लको पूर्वाद्र्ध चरणको नाटकमा असामान्य मनोविज्ञान {Bijay Mallako Purbardha Charanko Natakma Asamanya Manobigyan}.pdf is completed
# विद्याप्रसाद घिमिरेको जीवनी, व्यक्तित्व र कृतित्व {Bidhyaprasad Ghimireko Jeevani, Byaktitwo ra Krititwo}.pdf is completed
# विमलकुमार सुवेदीको जीवनी, व्यक्तित्व र कृतित्व{Bimalkumar Subediko Jibani, Byaktitwa ra Krititwa}.pdf is completed
# विश्वेश्वरप्रसाद कोइरालाका कथाको समाख्यानविधि {BishweshwarPrasad Koiralaka kathako Samakhyanabidhi}.pdf is completed
# विश्वेश्वरप्रसाद कोइरालाका कथामा यौनप्रतीक प्रयोग{Bishweshwor Prasad Koiralaka Kathama Yaunpratik Prayog}.pdf is completed
# विश्वेश्वरप्रसाद कोइरालाका कथामा विश्वदृष्टि {Bishweshwarprasad Koiralaka kathama bishwadristi}.pdf is completed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 34
#      31             pdf.close()
#      32             print(f'{filename} is completed')
# ---> 34 pdf_to_text('thesis_1','thesis_txt')
#
# Cell In[3], line 6, in measure_time.<locals>.wrapper(*args, **kwargs)
#       4 def wrapper(*args, **kwargs):
#       5     start_time = time.time()  # Record the start time
# ----> 6     result = func(*args, **kwargs)  # Execute the function
#       7     end_time = time.time()  # Record the end time
#       8     execution_time = end_time - start_time  # Calculate the execution time
#
# Cell In[7], line 24, in pdf_to_text(pdf_folder, text_folder, dpi)
#      22 byte_obj = pix.pil_tobytes(format="png", optimize=True)
#      23 img = Image.open(io.BytesIO(byte_obj))
# ---> 24 text = pytesseract.image_to_string(img, config=custom_config)
#      26 # Append the extracted text to the text file
#      27 with open(text_file, mode='a', encoding="utf-8") as f:
#
# File F:\Ankit Project\base\Lib\site-packages\pytesseract\pytesseract.py:423, in image_to_string(image, lang, config, nice, output_type, timeout)
#     418 """
#     419 Returns the result of a Tesseract OCR run on the provided image to string
#     420 """
#     421 args = [image, 'txt', lang, config, nice, timeout]
# --> 423 return {
#     424     Output.BYTES: lambda: run_and_get_output(*(args + [True])),
#     425     Output.DICT: lambda: {'text': run_and_get_output(*args)},
#     426     Output.STRING: lambda: run_and_get_output(*args),
#     427 }[output_type]()
#
# File F:\Ankit Project\base\Lib\site-packages\pytesseract\pytesseract.py:426, in image_to_string.<locals>.<lambda>()
#     418 """
#     419 Returns the result of a Tesseract OCR run on the provided image to string
#     420 """
#     421 args = [image, 'txt', lang, config, nice, timeout]
#     423 return {
#     424     Output.BYTES: lambda: run_and_get_output(*(args + [True])),
#     425     Output.DICT: lambda: {'text': run_and_get_output(*args)},
# --> 426     Output.STRING: lambda: run_and_get_output(*args),
#     427 }[output_type]()
#
# File F:\Ankit Project\base\Lib\site-packages\pytesseract\pytesseract.py:288, in run_and_get_output(image, extension, lang, config, nice, timeout, return_bytes)
#     277 with save(image) as (temp_name, input_filename):
#     278     kwargs = {
#     279         'input_filename': input_filename,
#     280         'output_filename_base': temp_name,
#    (...)
#     285         'timeout': timeout,
#     286     }
# --> 288     run_tesseract(**kwargs)
#     289     filename = f"{kwargs['output_filename_base']}{extsep}{extension}"
#     290     with open(filename, 'rb') as output_file:
#
# File F:\Ankit Project\base\Lib\site-packages\pytesseract\pytesseract.py:262, in run_tesseract(input_filename, output_filename_base, extension, lang, config, nice, timeout)
#     259     else:
#     260         raise TesseractNotFoundError()
# --> 262 with timeout_manager(proc, timeout) as error_string:
#     263     if proc.returncode:
#     264         raise TesseractError(proc.returncode, get_errors(error_string))
#
# File C:\Program Files\Python311\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File F:\Ankit Project\base\Lib\site-packages\pytesseract\pytesseract.py:127, in timeout_manager(proc, seconds)
#     125 try:
#     126     if not seconds:
# --> 127         yield proc.communicate()[1]
#     128         return
#     130     try:
#
# File C:\Program Files\Python311\Lib\subprocess.py:1209, in Popen.communicate(self, input, timeout)
#    1206     endtime = None
#    1208 try:
# -> 1209     stdout, stderr = self._communicate(input, endtime, timeout)
#    1210 except KeyboardInterrupt:
#    1211     # https://bugs.python.org/issue25942
#    1212     # See the detailed comment in .wait().
#    1213     if timeout is not None:
#
# File C:\Program Files\Python311\Lib\subprocess.py:1626, in Popen._communicate(self, input, endtime, orig_timeout)
#    1622 # Wait for the reader threads, or time out.  If we time out, the
#    1623 # threads remain reading and the fds left open in case the user
#    1624 # calls communicate again.
#    1625 if self.stdout is not None:
# -> 1626     self.stdout_thread.join(self._remaining_time(endtime))
#    1627     if self.stdout_thread.is_alive():
#    1628         raise TimeoutExpired(self.args, orig_timeout)
#
# File C:\Program Files\Python311\Lib\threading.py:1112, in Thread.join(self, timeout)
#    1109     raise RuntimeError("cannot join current thread")
#    1111 if timeout is None:
# -> 1112     self._wait_for_tstate_lock()
#    1113 else:
#    1114     # the behavior of a negative timeout isn't documented, but
#    1115     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1116     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File C:\Program Files\Python311\Lib\threading.py:1132, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1129     return
#    1131 try:
# -> 1132     if lock.acquire(block, timeout):
#    1133         lock.release()
#    1134         self._stop()
#
# KeyboardInterrupt:
